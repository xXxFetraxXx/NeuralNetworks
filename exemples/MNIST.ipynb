# %%
from NeuralNetworks import *
# %matplotlib widget

# %%
path = '/home/jovyan/work/datasets/'
inputs, outputs = MNIST.data(path)

# %%
net = MLP (layers = [28*28, 256, 256, 1])

# %%
net.train (inputs, outputs,
    num_epochs = 1500,
    batch_size = 16384
)
# Out:
# train epoch: 100%|██████████| 1500/1500 [00:07<00:00, 199.10it/s]

# %%
MNIST.evaluate(inputs,net)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Net output : 2
