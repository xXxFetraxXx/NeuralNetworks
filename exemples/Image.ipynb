# %%
from NeuralNetworks import *
# %matplotlib widget

# %%
img, inputs, outputs = image.url (
    url = "https://unesco.org.uk/site/assets/files/6266/the_forth_bridge_2.jpeg",
    img_size = 256
)

# %%
net = MLP (layers = [2, 256, 256, 256, 256, 256, 256, 3])

# %%
net.train (inputs, outputs, 1500, 16384)
# Out:
# train epoch: 100%|██████████| 1500/1500 [00:09<00:00, 151.61it/s]

# %%
image.plot(img,inputs,net)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
